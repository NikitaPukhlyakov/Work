# %% [markdown]
# # ElasticSearch (Userway)

# %% [markdown]
# https://dom.tutu.ru/pages/viewpage.action?pageId=89036396 - примеры запросов<br>
# https://dom.tutu.ru/pages/viewpage.action?pageId=73920579 - пример на агрегацию по разнице во времени<br>
# https://kibana-analytics-v2.infra.tutu.ru - Кибана Userway<br>
# https://kibana.logs.elc.tutu.ru/ - Кибана Эластик логов

# %% [markdown]
# ## Импорты

# %%
from elasticsearch import Elasticsearch
from elasticsearch_dsl import Search, Q, A, __version__
from elasticsearch_dsl.connections import connections
import time
import pandas as pd
import datetime

#client_uw = Elasticsearch(hosts=["http://analytics-3-6.elc.tutu.ru:9200"], timeout=600)
client_uw = Elasticsearch(hosts=["http://analytics-query.elc.tutu.ru:9200"], timeout=600)

dt_str = ['2018-06-20 00:00:00', '2018-06-21 00:00:00']

def datetime_to_utc (strtime, format='%Y-%m-%d %H:%M:%S'):
    return int(time.mktime(time.strptime(strtime, format)) * 1000)

dt = [datetime_to_utc(i) for i in dt_str]

def from_timestamp(t):
    t = int(t/1000)
    return datetime.datetime.fromtimestamp(t)#.date()

# %%
dt
# Out:
# [1529442000000, 1529528400000]

# %% [markdown]
# ## Пример запроса с использованием query_string

# %%
Q('query_string', query=
                                     'title:%s AND time:[%s TO %s] AND train_departure_station_code: (%s OR %s)' % (
                                         'train_schedule_with_date', dt[0], dt[1], '2000000', '2004000'))
# Out:
# QueryString(query='title:train_schedule_with_date AND time:[1529442000000 TO 1529528400000] AND train_departure_station_code: (2000000 OR 2004000)')

# %%
s_e = Search(using=client_uw).index('userway_alias').doc_type('event')

# %%
schedule_msk_spb_query = s_e.query(Q('query_string', query=
                                     'title:%s AND time:[%s TO %s] AND train_departure_station_code: (%s OR %s)' % (
                                         'train_schedule_with_date', dt[0], dt[1], '2000000', '2004000')))

schedule_msk_spb = schedule_msk_spb_query.execute()

# %%
schedule_msk_spb_query.execute()
# Out:
# <Response: [<Hit(userway_alpha/event/AWQaOuLH24KhZwUVgVnS): {'mtime': 1529448424136, 'type': 'page', 'title': 'train_sch...}>, <Hit(userway_alpha/event/AWQaq3n124KhZwUVhuRk): {'mtime': 1529455802871, 'type': 'page', 'title': 'train_sch...}>, <Hit(userway_alpha/event/AWQbm1TS24KhZwUVpaGf): {'mtime': 1529471522000, 'type': 'page', 'title': 'train_sch...}>, <Hit(userway_alpha/event/AWQb9wjQ24KhZwUVxP67): {'mtime': 1529477531856, 'type': 'page', 'title': 'train_sch...}>, <Hit(userway_alpha/event/AWQcVFQVbBWT9FmHmMnt): {'mtime': 1529483645975, 'type': 'page', 'title': 'train_sch...}>, <Hit(userway_alpha/event/AWQcVFUabBWT9FmHmMtE): {'mtime': 1529483646236, 'type': 'page', 'title': 'train_sch...}>, <Hit(userway_alpha/event/AWQcVHLebBWT9FmHmQiP): {'mtime': 1529483653856, 'type': 'page', 'title': 'train_sch...}>, <Hit(userway_alpha/event/AWQcUoEebBWT9FmHl5Wk): {'mtime': 1529483526432, 'type': 'page', 'title': 'train_sch...}>, <Hit(userway_alpha/event/AWQcUr9MbBWT9FmHl-8E): {'mtime': 1529483542339, 'type': 'page', 'title': 'train_sch...}>, <Hit(userway_alpha/event/AWQciX8lbBWT9FmHsXrc): {'mtime': 1529487130407, 'type': 'page', 'title': 'train_sch...}>]>

# %%
schedule_msk_spb.to_dict()#['hits']['total']
# Out:
# {'took': 255,
#  'timed_out': False,
#  '_shards': {'total': 144, 'successful': 144, 'failed': 0},
#  'hits': {'total': 297422,
#   'max_score': 4.0956903,
#   'hits': [{'_index': 'userway_alpha',
#     '_type': 'event',
#     '_id': 'AWQaOuLH24KhZwUVgVnS',
#     '_score': 4.0956903,
#     '_routing': '40200618-8631-434f-b161-fddf90ead226',
#     '_parent': '40200618-8631-434f-b161-fddf90ead226',
#     '_source': {'mtime': 1529448424136,
#      'type': 'page',
#      'title': 'train_schedule_with_date',
#      'time': 1529448376000,
#      'ip': '185.89.101.48',
#      'page_id': '5rMpPc8zMhU',
#      'route_type': 'oneway',
#      'search_date_timestamp': 1529528400000,
#      'site_version': 'full',
#      'train_arrival_station_code': 2024750,
#      'train_departure_station_code': 2004000,
#      'trains_available_count': 1,
#      'trains_count': 1,
#      'trains_elreg_count': 0,
#      'zone': 'main'}},
#    {'_index': 'userway_alpha',
#     '_type': 'event',
#     '_id': 'AWQaq3n124KhZwUVhuRk',
#     '_score': 4.0956903,
#     '_routing': '6e200618-4129-4ed0-8a66-af11eac3793a',
#     '_parent': '6e200618-4129-4ed0-8a66-af11eac3793a',
#     '_source': {'mtime': 1529455802871,
#      'type': 'page',
#      'title': 'train_schedule_with_date',
#      'time': 1529455795000,
#      'ip': '91.204.15.121',
#      'page_id': '5rMwJqICmUN',
#      'route_type': 'complex',
#      'search_date_timestamp': 1530306000000,
#      'site_version': 'full',
#      'train_arrival_station_code': 2000889,
#      'train_departure_station_code': 2004000,
#      'zone': 'main'}},
#    {'_index': 'userway_alpha',
#     '_type': 'event',
#     '_id': 'AWQbm1TS24KhZwUVpaGf',
#     '_score': 4.0956903,
#     '_routing': '9b080118-e535-4c25-8c30-38aabaedd28f',
#     '_parent': '9b080118-e535-4c25-8c30-38aabaedd28f',
#     '_source': {'mtime': 1529471522000,
#      'type': 'page',
#      'title': 'train_schedule_with_date',
#      'time': 1529471462000,
#      'ip': '188.162.65.9',
#      'page_id': '5rMLjeWFGbI',
#      'route_type': 'oneway',
#      'search_date_timestamp': 1534280400000,
#      'site_version': 'mobile',
#      'train_arrival_station_code': 2064788,
#      'train_departure_station_code': 2004000,
#      'trains_available_count': 4,
#      'trains_count': 4,
#      'trains_elreg_count': 4,
#      'zone': 'main'}},
#    {'_index': 'userway_alpha',
#     '_type': 'event',
#     '_id': 'AWQb9wjQ24KhZwUVxP67',
#     '_score': 4.0956903,
#     '_routing': '32240518-05d9-423c-8ea4-1d2f715989f1',
#     '_parent': '32240518-05d9-423c-8ea4-1d2f715989f1',
#     '_source': {'mtime': 1529477531856,
#      'type': 'page',
#      'title': 'train_schedule_with_date',
#      'time': 1529477467000,
#      'ip': '213.208.185.52',
#      'page_id': '5rMQVaCQvcL',
#      'referer_page': 'avia_offers',
#      'route_type': 'oneway',
#      'search_date_timestamp': 1530133200000,
#      'search_source': 'history',
#      'site_version': 'full',
#      'train_arrival_station_code': 2064188,
#      'train_departure_station_code': 2004000,
#      'trains_available_count': 2,
#      'trains_count': 2,
#      'trains_elreg_count': 2,
#      'zone': 'main'}},
#    {'_index': 'userway_alpha',
#     '_type': 'event',
#     '_id': 'AWQcVFQVbBWT9FmHmMnt',
#     '_score': 4.0956903,
#     '_routing': 'fd300917-2058-47e5-b6d7-f6ec038f7bb8',
#     '_parent': 'fd300917-2058-47e5-b6d7-f6ec038f7bb8',
#     '_source': {'mtime': 1529483645975,
#      'type': 'page',
#      'title': 'train_schedule_with_date',
#      'time': 1529483608000,
#      'ip': '95.55.26.91',
#      'page_id': '5rMWD9nbNrF',
#      'route_type': 'oneway',
#      'search_date_timestamp': 1532120400000,
#      'site_version': 'mobile',
#      'train_arrival_station_code': 2060450,
#      'train_departure_station_code': 2004000,
#      'trains_available_count': 3,
#      'trains_count': 3,
#      'trains_elreg_count': 3,
#      'zone': 'main'}},
#    {'_index': 'userway_alpha',
#     '_type': 'event',
#     '_id': 'AWQcVFUabBWT9FmHmMtE',
#     '_score': 4.0956903,
#     '_routing': '0e240817-0c80-4b13-8741-6cd298afbefa',
#     '_parent': '0e240817-0c80-4b13-8741-6cd298afbefa',
#     '_source': {'mtime': 1529483646236,
#      'type': 'page',
#      'title': 'train_schedule_with_date',
#      'time': 1529483608000,
#      'ip': '188.170.81.178',
#      'page_id': '5rMWDcoZ2XW',
#      'route_type': 'oneway',
#      'search_date_timestamp': 1532552400000,
#      'site_version': 'mobile',
#      'train_arrival_station_code': 2060370,
#      'train_departure_station_code': 2004000,
#      'trains_available_count': 1,
#      'trains_count': 1,
#      'trains_elreg_count': 1,
#      'zone': 'main'}},
#    {'_index': 'userway_alpha',
#     '_type': 'event',
#     '_id': 'AWQcVHLebBWT9FmHmQiP',
#     '_score': 4.0956903,
#     '_routing': '0e240817-0c80-4b13-8741-6cd298afbefa',
#     '_parent': '0e240817-0c80-4b13-8741-6cd298afbefa',
#     '_source': {'mtime': 1529483653856,
#      'type': 'page',
#      'title': 'train_schedule_with_date',
#      'time': 1529483574000,
#      'ip': '188.170.81.178',
#      'page_id': '5rMWB7PcrmL',
#      'route_type': 'oneway',
#      'search_date_timestamp': 1532552400000,
#      'site_version': 'mobile',
#      'train_arrival_station_code': 2060370,
#      'train_departure_station_code': 2004000,
#      'trains_available_count': 1,
#      'trains_count': 1,
#      'trains_elreg_count': 1,
#      'zone': 'main'}},
#    {'_index': 'userway_alpha',
#     '_type': 'event',
#     '_id': 'AWQcUoEebBWT9FmHl5Wk',
#     '_score': 4.0956903,
#     '_routing': 'fd300917-2058-47e5-b6d7-f6ec038f7bb8',
#     '_parent': 'fd300917-2058-47e5-b6d7-f6ec038f7bb8',
#     '_source': {'mtime': 1529483526432,
#      'type': 'page',
#      'title': 'train_schedule_with_date',
#      'time': 1529483467000,
#      'ip': '95.55.26.91',
#      'page_id': '5rMWuLM46qS',
#      'route_type': 'oneway',
#      'search_date_timestamp': 1529874000000,
#      'site_version': 'mobile',
#      'train_arrival_station_code': 2060450,
#      'train_departure_station_code': 2004000,
#      'trains_available_count': 3,
#      'trains_count': 3,
#      'trains_elreg_count': 3,
#      'zone': 'main'}},
#    {'_index': 'userway_alpha',
#     '_type': 'event',
#     '_id': 'AWQcUr9MbBWT9FmHl-8E',
#     '_score': 4.0956903,
#     '_routing': 'fd300917-2058-47e5-b6d7-f6ec038f7bb8',
#     '_parent': 'fd300917-2058-47e5-b6d7-f6ec038f7bb8',
#     '_source': {'mtime': 1529483542339,
#      'type': 'page',
#      'title': 'train_schedule_with_date',
#      'time': 1529483519000,
#      'ip': '95.55.26.91',
#      'page_id': '5rMWxT0vbQz',
#      'route_type': 'oneway',
#      'search_date_timestamp': 1529528400000,
#      'site_version': 'mobile',
#      'train_arrival_station_code': 2060450,
#      'train_departure_station_code': 2004000,
#      'trains_available_count': 3,
#      'trains_count': 3,
#      'trains_elreg_count': 3,
#      'zone': 'main'}},
#    {'_index': 'userway_alpha',
#     '_type': 'event',
#     '_id': 'AWQciX8lbBWT9FmHsXrc',
#     '_score': 4.0956903,
#     '_routing': '67080618-327c-4329-87d5-ec94ae292943',
#     '_parent': '67080618-327c-4329-87d5-ec94ae292943',
#     '_source': {'mtime': 1529487130407,
#      'type': 'page',
#      'title': 'train_schedule_with_date',
#      'time': 1529487092000,
#      'ip': '217.70.29.131',
#      'page_id': '5rMZSQ8zKKw',
#      'route_type': 'oneway',
#      'search_date_timestamp': 1530565200000,
#      'site_version': 'full',
#      'train_arrival_station_code': 2000000,
#      'train_departure_station_code': 2004000,
#      'trains_available_count': 49,
#      'trains_count': 49,
#      'trains_elreg_count': 15,
#      'zone': 'english'}}]}}

# %%
schedule_msk_spb.hits.total
# Out:
# 297422

# %% [markdown]
# ## Пример запроса с использованием term

# %%
s_g = Search(using=client_uw).index('userway_alias').doc_type('goal')

# %%
time_query = Q('range', time={'gt':dt_str[0], 'lte':dt_str[1], 
                                                'format':'yyyy-MM-dd HH:mm:ss', 'time_zone':'+03:00'})

# %%
dt_str[0]
# Out:
# '2018-06-20 00:00:00'

# %%
cheap_orders_query = s_g.query(Q('term', type='zhd_order')&
                               time_query&
                               Q('terms', count=[2, 3, 4]))

# %% [markdown]
# ## Scan

# %%
cheap_orders = pd.DataFrame(columns=['object_id', 'session_id'])

i = 0
for res in cheap_orders_query.scan():
    cheap_orders.loc[i] =[res.object, res.meta.parent]
    i += 1

# %%
cheap_orders.head()
# Out:
#   object_id                            session_id
# 0  18373587  2c200618-9515-47ff-a828-3cfd86b4dca4
# 1  18375992  ad180618-e7c2-4d24-9219-54f78724ecb4
# 2  18368199  9d200618-472a-4bac-bb7f-de986de860d3
# 3  18370462  6f230816-dcbd-461f-866a-4aa05ac78ac7
# 4  18372739  5b211216-d570-45e7-9c71-d17783982744

# %%
with open('cheap_orders.csv','w') as file:
    for res in cheap_orders_query.scan():
        res_d = res.to_dict()
        print('\t'.join(map(str,[res.object, res.meta.parent, res_d.get('profit', 'None')])),file=file)

# %%
pd.read_csv('cheap_orders.csv', sep='\t', names=['object_id', 'session_id']).head()
# Out:
#    object_id                            session_id
# 0   18373587  2c200618-9515-47ff-a828-3cfd86b4dca4
# 1   18375992  ad180618-e7c2-4d24-9219-54f78724ecb4
# 2   18368199  9d200618-472a-4bac-bb7f-de986de860d3
# 3   18370462  6f230816-dcbd-461f-866a-4aa05ac78ac7
# 4   18372739  5b211216-d570-45e7-9c71-d17783982744

# %% [markdown]
# ## Запросы parent-child

# %%
schedule_msk_spb_query = s_e.query(Q('prefix', title='train_schedule')&
                                   Q('range', time={'gte':dt_str[0], 'lte':dt_str[1], 
                                                    'format':'yyyy-MM-dd HH:mm:ss', 'time_zone':'+03:00'})&
                                   Q('terms', train_departure_station_code=[2000000, 2004000])&
                                   Q('has_parent', query=
                                     Q('has_child', query=
                                       Q('term', device_type='smartphone'), 
                                       type='client'), 
                                     type='session'))

schedule_msk_spb = schedule_msk_spb_query.execute()

# %%
ss.query(~Q('has_child', query=
          Q('term', title='tours_jarvel'),
          type='event')|
         Q('has_child', query=
          Q('term', title='tours_hotel'),
          type='event'))

# %%
schedule_msk_spb.hits.total
# Out:
# 165023

# %%
s_e.query(Q('term', title='tours_search')&
                                   Q('has_parent', query=
                                     Q('has_child', query=
                                       Q('term', title='tours_order'), 
                                       type='event'), 
                                     type='session'))

# %%
# Выгрузить session id по запросу выше

# %% [markdown]
# ## Агрегации

# %%
dt_str_1 = ['2018-06-20 00:00:00', '2018-06-21 23:59:59']

# %% [markdown]
# #### Агрегация по времени

# %%
schedule_smartphone_query = s_e.query(Q('term', title='train_schedule_with_date')&
                                      Q('range', time={'gte':dt_str_1[0], 'lte':dt_str_1[1], 
                                                       'format':'yyyy-MM-dd HH:mm:ss', 'time_zone':'+03:00'})&
                                      Q('has_parent', query=
                                        Q('has_child', query=
                                          Q('term', device_type='smartphone'), 
                                          type='client'), 
                                        type='session'))

# %%
schedule_smartphone_query.aggs.bucket('per_day', 'date_histogram', field='time', interval='day', time_zone = 'Europe/Moscow')\
               .metric('visitors','cardinality', field = '_parent')
# Out:
# DateHistogram(aggs={'visitors': Cardinality(field='_parent')}, field='time', interval='day', time_zone='Europe/Moscow')

# %%
schedule_smartphone = schedule_smartphone_query.execute()

# %%
schedule_smartphone.to_dict()
# Out:
# {'took': 15935,
#  'timed_out': False,
#  '_shards': {'total': 144, 'successful': 144, 'failed': 0},
#  'hits': {'total': 869182,
#   'max_score': 4.3910675,
#   'hits': [{'_index': 'userway_alpha',
#     '_type': 'event',
#     '_id': 'AWQZ9F_O24KhZwUVekQo',
#     '_score': 4.3910675,
#     '_routing': '36311017-2542-4435-b01f-28bf6fc0c0bf',
#     '_parent': '36311017-2542-4435-b01f-28bf6fc0c0bf',
#     '_source': {'mtime': 1529443803087,
#      'type': 'page',
#      'title': 'train_schedule_with_date',
#      'time': 1529443709000,
#      'ip': '37.168.26.178',
#      'page_id': '5rMls-WGrBk',
#      'route_type': 'oneway',
#      'search_date_timestamp': 1533330000000,
#      'site_version': 'mobile',
#      'train_arrival_station_code': 8700400,
#      'train_departure_station_code': 2000000,
#      'trains_available_count': 0,
#      'trains_count': 0,
#      'trains_elreg_count': 0,
#      'zone': 'main'}},
#    {'_index': 'userway_alpha',
#     '_type': 'event',
#     '_id': 'AWQZ9GBk24KhZwUVekUO',
#     '_score': 4.3910675,
#     '_routing': '36311017-2542-4435-b01f-28bf6fc0c0bf',
#     '_parent': '36311017-2542-4435-b01f-28bf6fc0c0bf',
#     '_source': {'mtime': 1529443803238,
#      'type': 'page',
#      'title': 'train_schedule_with_date',
#      'time': 1529443752000,
#      'ip': '37.168.26.178',
#      'page_id': '5rMlvAzOh2w',
#      'route_type': 'oneway',
#      'search_date_timestamp': 1531342800000,
#      'site_version': 'mobile',
#      'train_arrival_station_code': 8700400,
#      'train_departure_station_code': 2000000,
#      'trains_available_count': 1,
#      'trains_count': 1,
#      'trains_elreg_count': 0,
#      'zone': 'main'}},
#    {'_index': 'userway_alpha',
#     '_type': 'event',
#     '_id': 'AWQZ8ack24KhZwUVegDg',
#     '_score': 4.3910675,
#     '_routing': '4e041117-978d-4838-a5d6-b61e89bd0519',
#     '_parent': '4e041117-978d-4838-a5d6-b61e89bd0519',
#     '_source': {'mtime': 1529443624740,
#      'type': 'page',
#      'title': 'train_schedule_with_date',
#      'time': 1529443594000,
#      'ip': '37.29.88.30',
#      'page_id': '5rMlm9Z9Y4m',
#      'route_type': 'oneway',
#      'search_date_timestamp': 1533330000000,
#      'site_version': 'mobile',
#      'train_arrival_station_code': 2034130,
#      'train_departure_station_code': 2034000,
#      'trains_available_count': 6,
#      'trains_count': 6,
#      'trains_elreg_count': 6,
#      'zone': 'main'}},
#    {'_index': 'userway_alpha',
#     '_type': 'event',
#     '_id': 'AWQZ8ol424KhZwUVehOH',
#     '_score': 4.3910675,
#     '_routing': '36311017-2542-4435-b01f-28bf6fc0c0bf',
#     '_parent': '36311017-2542-4435-b01f-28bf6fc0c0bf',
#     '_source': {'mtime': 1529443682681,
#      'type': 'page',
#      'title': 'train_schedule_with_date',
#      'time': 1529443646000,
#      'ip': '37.168.26.178',
#      'page_id': '5rMlpgOKbXy',
#      'route_type': 'oneway',
#      'search_date_timestamp': 1529528400000,
#      'site_version': 'mobile',
#      'train_arrival_station_code': 8700400,
#      'train_departure_station_code': 2000000,
#      'trains_available_count': 1,
#      'trains_count': 1,
#      'trains_elreg_count': 0,
#      'zone': 'main'}},
#    {'_index': 'userway_alpha',
#     '_type': 'event',
#     '_id': 'AWQZ8ouC24KhZwUVehgF',
#     '_score': 4.3910675,
#     '_routing': '36311017-2542-4435-b01f-28bf6fc0c0bf',
#     '_parent': '36311017-2542-4435-b01f-28bf6fc0c0bf',
#     '_source': {'mtime': 1529443683202,
#      'type': 'page',
#      'title': 'train_schedule_with_date',
#      'time': 1529443641000,
#      'ip': '37.168.26.178',
#      'page_id': '5rMloYTcfK5',
#      'route_type': 'oneway',
#      'search_date_timestamp': 1529528400000,
#      'site_version': 'mobile',
#      'train_arrival_station_code': 8700400,
#      'train_departure_station_code': 2000000,
#      'trains_available_count': 1,
#      'trains_count': 1,
#      'trains_elreg_count': 0,
#      'zone': 'main'}},
#    {'_index': 'userway_alpha',
#     '_type': 'event',
#     '_id': 'AWQZ83oR24KhZwUVejo3',
#     '_score': 4.3910675,
#     '_routing': '36311017-2542-4435-b01f-28bf6fc0c0bf',
#     '_parent': '36311017-2542-4435-b01f-28bf6fc0c0bf',
#     '_source': {'mtime': 1529443744275,
#      'type': 'page',
#      'title': 'train_schedule_with_date',
#      'time': 1529443725000,
#      'ip': '37.168.26.178',
#      'page_id': '5rMlt_AZ25H',
#      'route_type': 'oneway',
#      'search_date_timestamp': 1531083600000,
#      'site_version': 'mobile',
#      'train_arrival_station_code': 8700400,
#      'train_departure_station_code': 2000000,
#      'trains_available_count': 0,
#      'trains_count': 0,
#      'trains_elreg_count': 0,
#      'zone': 'main'}},
#    {'_index': 'userway_alpha',
#     '_type': 'event',
#     '_id': 'AWQZ833124KhZwUVej1o',
#     '_score': 4.3910675,
#     '_routing': '36311017-2542-4435-b01f-28bf6fc0c0bf',
#     '_parent': '36311017-2542-4435-b01f-28bf6fc0c0bf',
#     '_source': {'mtime': 1529443745271,
#      'type': 'page',
#      'title': 'train_schedule_with_date',
#      'time': 1529443734000,
#      'ip': '37.168.26.178',
#      'page_id': '5rMluwaVT-3',
#      'route_type': 'oneway',
#      'search_date_timestamp': 1531170000000,
#      'site_version': 'mobile',
#      'train_arrival_station_code': 8700400,
#      'train_departure_station_code': 2000000,
#      'trains_available_count': 0,
#      'trains_count': 0,
#      'trains_elreg_count': 0,
#      'zone': 'main'}},
#    {'_index': 'userway_alpha',
#     '_type': 'event',
#     '_id': 'AWQZ9Fwx24KhZwUVej5k',
#     '_score': 4.3910675,
#     '_routing': '36311017-2542-4435-b01f-28bf6fc0c0bf',
#     '_parent': '36311017-2542-4435-b01f-28bf6fc0c0bf',
#     '_source': {'mtime': 1529443802161,
#      'type': 'page',
#      'title': 'train_schedule_with_date',
#      'time': 1529443743000,
#      'ip': '37.168.26.178',
#      'page_id': '5rMlv0K1Kbr',
#      'route_type': 'oneway',
#      'search_date_timestamp': 1531256400000,
#      'site_version': 'mobile',
#      'train_arrival_station_code': 8700400,
#      'train_departure_station_code': 2000000,
#      'trains_available_count': 0,
#      'trains_count': 0,
#      'trains_elreg_count': 0,
#      'zone': 'main'}},
#    {'_index': 'userway_alpha',
#     '_type': 'event',
#     '_id': 'AWQZ9U3224KhZwUVem8p',
#     '_score': 4.3910675,
#     '_routing': '0a150618-23dc-462b-b6a4-b20cd8d5d2d8',
#     '_parent': '0a150618-23dc-462b-b6a4-b20cd8d5d2d8',
#     '_source': {'mtime': 1529443864054,
#      'type': 'page',
#      'title': 'train_schedule_with_date',
#      'time': 1529443839000,
#      'ip': '217.118.95.99',
#      'page_id': '5rMlALzEQcu',
#      'route_type': 'oneway',
#      'search_date_timestamp': 1529960400000,
#      'site_version': 'mobile',
#      'train_arrival_station_code': 2064165,
#      'train_departure_station_code': 2014000,
#      'trains_available_count': 1,
#      'trains_count': 1,
#      'trains_elreg_count': 0,
#      'zone': 'main'}},
#    {'_index': 'userway_alpha',
#     '_type': 'event',
#     '_id': 'AWQZ83OZ24KhZwUVei6D',
#     '_score': 4.3910675,
#     '_routing': '36311017-2542-4435-b01f-28bf6fc0c0bf',
#     '_parent': '36311017-2542-4435-b01f-28bf6fc0c0bf',
#     '_source': {'mtime': 1529443742617,
#      'type': 'page',
#      'title': 'train_schedule_with_date',
#      'time': 1529443698000,
#      'ip': '37.168.26.178',
#      'page_id': '5rMlso0WQNH',
#      'route_type': 'oneway',
#      'search_date_timestamp': 1533502800000,
#      'site_version': 'mobile',
#      'train_arrival_station_code': 8700400,
#      'train_departure_station_code': 2000000,
#      'trains_available_count': 0,
#      'trains_count': 0,
#      'trains_elreg_count': 0,
#      'zone': 'main'}}]},
#  'aggregations': {'per_day': {'buckets': [{'key_as_string': '20.06.2018',
#      'key': 1529442000000,
#      'doc_count': 439200,
#      'visitors': {'value': 144937}},
#     {'key_as_string': '21.06.2018',
#      'key': 1529528400000,
#      'doc_count': 429982,
#      'visitors': {'value': 135971}}]}}}

# %%
print('date', 'count', 'unique')
for i in schedule_smartphone.aggregations.per_day.buckets:
    print(from_timestamp(i.key), i.doc_count, i.visitors.value)
# Out:
# date count unique
# 2018-06-20 00:00:00 439200 144937
# 2018-06-21 00:00:00 429982 135971

# %% [markdown]
# #### Агрегация по другим полям

# %%
schedule_msk_spb_1_query = s_e.query(Q('term', title='train_schedule_with_date')&
                                   Q('range', time={'gte':dt_str[0], 'lte':dt_str[1], 
                                                    'format':'yyyy-MM-dd HH:mm:ss', 'time_zone':'+03:00'})&
                                   Q('terms', train_departure_station_code=[2000000, 2004000])&
                                   Q('has_parent', query=
                                     Q('has_child', query=
                                       Q('term', device_type='smartphone'), 
                                       type='client'), 
                                     type='session'))

# %%
schedule_msk_spb_1_query.aggs.bucket('arr_stations', 'terms', field ='train_arrival_station_code', size=0)
# Out:
# Terms(field='train_arrival_station_code', size=0)

# %%
schedule_msk_spb_1 = schedule_msk_spb_1_query.execute()

# %%
schedule_msk_spb_1.to_dict()
# Out:
# {'took': 16544,
#  'timed_out': False,
#  '_shards': {'total': 144, 'successful': 144, 'failed': 0},
#  'hits': {'total': 120544,
#   'max_score': 4.1794524,
#   'hits': [{'_index': 'userway_alpha',
#     '_type': 'event',
#     '_id': 'AWQbm1TS24KhZwUVpaGf',
#     '_score': 4.1794524,
#     '_routing': '9b080118-e535-4c25-8c30-38aabaedd28f',
#     '_parent': '9b080118-e535-4c25-8c30-38aabaedd28f',
#     '_source': {'mtime': 1529471522000,
#      'type': 'page',
#      'title': 'train_schedule_with_date',
#      'time': 1529471462000,
#      'ip': '188.162.65.9',
#      'page_id': '5rMLjeWFGbI',
#      'route_type': 'oneway',
#      'search_date_timestamp': 1534280400000,
#      'site_version': 'mobile',
#      'train_arrival_station_code': 2064788,
#      'train_departure_station_code': 2004000,
#      'trains_available_count': 4,
#      'trains_count': 4,
#      'trains_elreg_count': 4,
#      'zone': 'main'}},
#    {'_index': 'userway_alpha',
#     '_type': 'event',
#     '_id': 'AWQcVFQVbBWT9FmHmMnt',
#     '_score': 4.1794524,
#     '_routing': 'fd300917-2058-47e5-b6d7-f6ec038f7bb8',
#     '_parent': 'fd300917-2058-47e5-b6d7-f6ec038f7bb8',
#     '_source': {'mtime': 1529483645975,
#      'type': 'page',
#      'title': 'train_schedule_with_date',
#      'time': 1529483608000,
#      'ip': '95.55.26.91',
#      'page_id': '5rMWD9nbNrF',
#      'route_type': 'oneway',
#      'search_date_timestamp': 1532120400000,
#      'site_version': 'mobile',
#      'train_arrival_station_code': 2060450,
#      'train_departure_station_code': 2004000,
#      'trains_available_count': 3,
#      'trains_count': 3,
#      'trains_elreg_count': 3,
#      'zone': 'main'}},
#    {'_index': 'userway_alpha',
#     '_type': 'event',
#     '_id': 'AWQcVFUabBWT9FmHmMtE',
#     '_score': 4.1794524,
#     '_routing': '0e240817-0c80-4b13-8741-6cd298afbefa',
#     '_parent': '0e240817-0c80-4b13-8741-6cd298afbefa',
#     '_source': {'mtime': 1529483646236,
#      'type': 'page',
#      'title': 'train_schedule_with_date',
#      'time': 1529483608000,
#      'ip': '188.170.81.178',
#      'page_id': '5rMWDcoZ2XW',
#      'route_type': 'oneway',
#      'search_date_timestamp': 1532552400000,
#      'site_version': 'mobile',
#      'train_arrival_station_code': 2060370,
#      'train_departure_station_code': 2004000,
#      'trains_available_count': 1,
#      'trains_count': 1,
#      'trains_elreg_count': 1,
#      'zone': 'main'}},
#    {'_index': 'userway_alpha',
#     '_type': 'event',
#     '_id': 'AWQcVHLebBWT9FmHmQiP',
#     '_score': 4.1794524,
#     '_routing': '0e240817-0c80-4b13-8741-6cd298afbefa',
#     '_parent': '0e240817-0c80-4b13-8741-6cd298afbefa',
#     '_source': {'mtime': 1529483653856,
#      'type': 'page',
#      'title': 'train_schedule_with_date',
#      'time': 1529483574000,
#      'ip': '188.170.81.178',
#      'page_id': '5rMWB7PcrmL',
#      'route_type': 'oneway',
#      'search_date_timestamp': 1532552400000,
#      'site_version': 'mobile',
#      'train_arrival_station_code': 2060370,
#      'train_departure_station_code': 2004000,
#      'trains_available_count': 1,
#      'trains_count': 1,
#      'trains_elreg_count': 1,
#      'zone': 'main'}},
#    {'_index': 'userway_alpha',
#     '_type': 'event',
#     '_id': 'AWQcUoEebBWT9FmHl5Wk',
#     '_score': 4.1794524,
#     '_routing': 'fd300917-2058-47e5-b6d7-f6ec038f7bb8',
#     '_parent': 'fd300917-2058-47e5-b6d7-f6ec038f7bb8',
#     '_source': {'mtime': 1529483526432,
#      'type': 'page',
#      'title': 'train_schedule_with_date',
#      'time': 1529483467000,
#      'ip': '95.55.26.91',
#      'page_id': '5rMWuLM46qS',
#      'route_type': 'oneway',
#      'search_date_timestamp': 1529874000000,
#      'site_version': 'mobile',
#      'train_arrival_station_code': 2060450,
#      'train_departure_station_code': 2004000,
#      'trains_available_count': 3,
#      'trains_count': 3,
#      'trains_elreg_count': 3,
#      'zone': 'main'}},
#    {'_index': 'userway_alpha',
#     '_type': 'event',
#     '_id': 'AWQcUr9MbBWT9FmHl-8E',
#     '_score': 4.1794524,
#     '_routing': 'fd300917-2058-47e5-b6d7-f6ec038f7bb8',
#     '_parent': 'fd300917-2058-47e5-b6d7-f6ec038f7bb8',
#     '_source': {'mtime': 1529483542339,
#      'type': 'page',
#      'title': 'train_schedule_with_date',
#      'time': 1529483519000,
#      'ip': '95.55.26.91',
#      'page_id': '5rMWxT0vbQz',
#      'route_type': 'oneway',
#      'search_date_timestamp': 1529528400000,
#      'site_version': 'mobile',
#      'train_arrival_station_code': 2060450,
#      'train_departure_station_code': 2004000,
#      'trains_available_count': 3,
#      'trains_count': 3,
#      'trains_elreg_count': 3,
#      'zone': 'main'}},
#    {'_index': 'userway_alpha',
#     '_type': 'event',
#     '_id': 'AWQchqM2bBWT9FmHsB7s',
#     '_score': 4.1794524,
#     '_routing': '47220418-ef73-4c12-ab28-7a43cb734c52',
#     '_parent': '47220418-ef73-4c12-ab28-7a43cb734c52',
#     '_source': {'mtime': 1529486943032,
#      'type': 'page',
#      'title': 'train_schedule_with_date',
#      'time': 1529486863000,
#      'ip': '5.76.223.23',
#      'page_id': '5rMZEyjkgBZ',
#      'route_type': 'oneway',
#      'search_date_timestamp': 1530306000000,
#      'site_version': 'mobile',
#      'train_arrival_station_code': 2700152,
#      'train_departure_station_code': 2004000,
#      'trains_available_count': 0,
#      'trains_count': 0,
#      'trains_elreg_count': 0,
#      'zone': 'main'}},
#    {'_index': 'userway_alpha',
#     '_type': 'event',
#     '_id': 'AWQcozZ0bBWT9FmHvVoX',
#     '_score': 4.1794524,
#     '_routing': '17200618-15e6-44b4-8555-199e03cb20d6',
#     '_parent': '17200618-15e6-44b4-8555-199e03cb20d6',
#     '_source': {'mtime': 1529488815734,
#      'type': 'page',
#      'title': 'train_schedule_with_date',
#      'time': 1529488785000,
#      'ip': '193.106.161.52',
#      'page_id': '5rM-rLIgSls',
#      'route_type': 'oneway',
#      'search_date_timestamp': 
# 2708880 1
# 2708920 1
# 2709941 1
# 2900689 1
# 2900866 1
# 5100139 1
# 5310017 1
# 5400011 1
# 5433425 1
# 5433845 1
# 5513912 1
# 5613680 1
# 5900893 1
# 6200002 1
# 6200003 1
# 6200175 1
# 6600386 1
# 6700890 1
# 7216003 1
# 7216050 1
# 7500120 1
# 7800558 1
# 7900303 1
# 8040260 1
# 8079165 1

# %% [markdown]
# ## Exists

# %%
s1 = s_e.query(Q('term', title='etrain_buy_button_click')
              & time_query
              & ~Q('exists',field='train_found_train_hash')
              & Q('has_parent',  query = Q('has_child', query = Q('term', is_real='true'), type='client'),\
                  type='session'))

s1.aggs.bucket('hashs','terms', field = 'train_found_train_hash', size=7000)
res1 = s1.execute()

# %% [markdown]
# ## Фильтры

# %%
# пример построения воронки из реальной АБ

# %%
dt_str_ab = ['2018-03-27 13:30:59', '2018-04-04 10:45:59']

# %%
s_uw = Search(using=client_uw).index('userway_alias').doc_type('session')

# %%
visit = A('filter', Q('has_child', query=
                      Q('prefix', title='train')&
                      Q('range', time={'gte':dt_str_ab[0], 'lte':dt_str_ab[1], 
                                       'format':'yyyy-MM-dd HH:mm:ss', "time_zone":"+03:00"}),
                      type='event').to_dict())

seats = A('filter', Q('has_child', query=
                      Q('term', title='train_seats')&
                      Q('range', time={'gte':dt_str_ab[0], 'lte':dt_str_ab[1], 
                                       'format':'yyyy-MM-dd HH:mm:ss', "time_zone":"+03:00"}),
                      type='event').to_dict())

passengers = A('filter', Q('has_child', query=
                                 Q('term', title='train_passengers')&
                                 Q('range', time={'gte':dt_str_ab[0], 'lte':dt_str_ab[1], 
                                                  'format':'yyyy-MM-dd HH:mm:ss', "time_zone":"+03:00"}), 
                           type='event').to_dict())

payment = A('filter', Q('has_child', query=
                                 Q('term', title='train_payment')&
                                 Q('range', time={'gte':dt_str_ab[0], 'lte':dt_str_ab[1], 
                                                  'format':'yyyy-MM-dd HH:mm:ss', "time_zone":"+03:00"}),
                        type='event').to_dict())

final = A('filter', Q('has_child', query=
                                 Q('term', title='train_final')&
                                 Q('range', time={'gte':dt_str_ab[0], 'lte':dt_str_ab[1], 
                                                  'format':'yyyy-MM-dd HH:mm:ss', "time_zone":"+03:00"}),
                      type='event').to_dict())

billing = A('filter', Q('has_child', query=
                                 Q('term', title='train_billing')&
                                 Q('range', time={'gte':dt_str_ab[0], 'lte':dt_str_ab[1], 
                                                  'format':'yyyy-MM-dd HH:mm:ss', "time_zone":"+03:00"}),
                        type='event').to_dict())

zhd_order = A('filter', Q('has_child', query=
                                 Q('term', type='zhd_order')&
                                 Q('range', time={'gte':dt_str_ab[0], 'lte':dt_str_ab[1], 
                                                  'format':'yyyy-MM-dd HH:mm:ss', "time_zone":"+03:00"}),
                          type='goal').to_dict())

# %%
ab = ['train_toilets_and_conds_on_v04', 'train_toilets_and_conds_off_v04']

# %%
def get_funnel(ab):
    #все сессии не ботов с нужным вариантом АБ
    sq = s_uw.query(Q('has_child', query=
                      Q('term', device_type='smartphone'), 
                      type='client')&
                    Q('term', ab='%s' % (ab[0]))&
                    ~Q('term', ab='%s' % (ab[1]))).params(size=0)
    
    #навешиваем фильтры
    sq.aggs.bucket('train_seats', seats).\
    bucket('train_passengers', passengers).bucket('train_payment', payment).bucket('train_final', final).\
    bucket('train_billing', billing).bucket('zhd_order', zhd_order)
    
    return sq.execute()

# %%
#строим воронку для варианта on
res_on = get_funnel(ab)

# %%
res_on.to_dict()
# Out:
# {'took': 8227,
#  'timed_out': False,
#  '_shards': {'total': 144, 'successful': 144, 'failed': 0},
#  'hits': {'total': 154329, 'max_score': 0.0, 'hits': []},
#  'aggregations': {'train_seats': {'doc_count': 115631,
#    'train_passengers': {'doc_count': 20287,
#     'train_payment': {'doc_count': 11223,
#      'train_final': {'doc_count': 10012,
#       'train_billing': {'doc_count': 9156,
#        'zhd_order': {'doc_count': 8478}}}}}}}}

# %%
#строим воронку для варианта off
res_off = get_funnel(ab[::-1])

# %%
res_off.to_dict()
# Out:
# {'took': 10747,
#  'timed_out': False,
#  '_shards': {'total': 144, 'successful': 144, 'failed': 0},
#  'hits': {'total': 153289, 'max_score': 0.0, 'hits': []},
#  'aggregations': {'train_seats': {'doc_count': 114846,
#    'train_passengers': {'doc_count': 20377,
#     'train_payment': {'doc_count': 11252,
#      'train_final': {'doc_count': 9988,
#       'train_billing': {'doc_count': 9168,
#        'zhd_order': {'doc_count': 8514}}}}}}}}

# %% [markdown]
# # Запрос к эластику логов

# %%
from elasticsearch import Elasticsearch
from elasticsearch_dsl import Search, Q, A

HOST_LOGS = "http://kibana.logs.elc.tutu.ru:9280"
CLIENT_LOGS = Elasticsearch(hosts=HOST_LOGS, timeout=300)

def logs_search():
    return Search(using=CLIENT_LOGS).doc_type('logs')

dt_str = ['2019-06-01 00:00:00', '2019-06-30 23:59:59']

dt = [datetime_to_utc (i) for i in dt_str]

# %%
sms_subsсription_search = logs_search()
local_time_query = sms_subsсription_search.query(
    Q('term', log='usage_log')
    & Q('query_string',
        query='message:train_schedule_local_time AND @timestamp:[{} TO {}]'.format(*dt)
       )
)

# %%
i = 0
for res in local_time_query.scan():
    print(type(res['@timestamp']))
    print(res['@timestamp'].strptime())
    i += 1
    if i>1:
        break
# Out:
# <class 'str'>
# 2019-06-01T12:59:14.372Z
# <class 'str'>
# 2019-06-04T12:24:07.859Z

# %%
with open('data/local_time.csv', 'w',  encoding='utf-8') as f:
    start = time.time()
    for res in local_time_query.scan():
        fields = [res.code, res['@timestamp'], res.message]
        print('\t'.join(list(map(str, fields))), file=f)
        i += 1
        if i % 100 == 0 or i == total:
            print('read {} rows ({:.2%}) in {:.2f} sec.'.format(i, i / total, time.time() - start))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-0944b97b1de5> in <module>()
#       5         print('\t'.join(list(map(str, fields))), file=f)
#       6         i += 1
# ----> 7         if i % 100 == 0 or i == total:
#       8             print('read {} rows ({:.2%}) in {:.2f} sec.'.format(i, i / total, time.time() - start))
#
# NameError: name 'total' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-02ca04bb105f> in <module>()
# ----> 1 s = ss.query(Q('range', mtime={'gte': dt[0], 'lte': dt[1],'format': 'yyyy-MM-dd HH:mm:ss',
#       2                                  "time_zone": "+03:00"}))
#
# NameError: name 'ss' is not defined
