# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Часть 1. Python

# %%
#Напишите функцию, которая вычленяет из текста все числа и возвражает их списком

def take_numb(my_string):
    
    num = {str(i) for i in range(0,10)}
    res = list()
    cur = list()
    l = len(my_string)
    c = 0
    
    for x in my_string: 
        
        c += 1
        
        if x in num:
            cur.append(x)
            
        if (x not in num or c == l) and len(cur)>0:
            res.append(int(''.join(cur)))
            cur = list()
                       
    return res
                       

print(take_numb('I was born in 1998'))  #[1998]
print(take_numb('She had got 5 cats and 3 kittens')) #[5, 3]
print(take_numb('Does it really cost 500$? Or maybe 450$?')) #[500, 450]
# Out:
# [1998]
# [5, 3]
# [500, 450]

# %%
#Напишите функцию, которая принимает на вход словарь, а возвращает все уникальные значения словаря списком

def get_distinct_dic(dic):
    a = set()
    for x in dic.items():
        a.add(x[1])

    return list(a)

get_distinct_dic({'jan':47, 'feb':52, 'march':47, 'April':44, 'May':52, 'June':53, 'july':54, 'Aug':44, 'Sept':54}) # [47, 52, 44, 53, 54]
# Out:
# [44, 47, 52, 53, 54]

# %%
#Напишите функцию, которая принимает на вход список, а возвращает все уникальные 
#значения списка + печатает минимум и максимум списка

def get_distinct_list(dic):
    
    min_ = dic[0]
    max_ = dic[0]
    a = set()
    
    for i in range(len(dic)):
        
        a.add(dic[i])
        
        if dic[i] > max_:
            max_ = dic[i] 
            
        if dic[i] < min_:
            min_ = dic[i]
            
    return [list(a), min_, max_]

get_distinct_list([9123, 31, 1938, 9123, 1, 249, 912, 10, 31, 213, 81, 10]) # [31, 1938, 9123, 1, 249, 912, 010, 213, 81], min = 1, max = 9123
# Out:
# [[1, 9123, 10, 912, 81, 1938, 213, 249, 31], 1, 9123]

# %%
#Выведите сколько раз в тексте встречается каждое слово (не учитывая регистр), каждый знак преминания и каждая буква

sample_test = "Гостиная Анны Павловны начала понемногу наполняться. Приехала высшая знать Петербурга, люди самые разнородные по возрастам и характерам, но одинаковые по обществу, в каком все жили; приехала дочь князя Василия, красавица Элен, заехавшая за отцом, чтобы с ним вместе ехать на праздник посланника. Она была в шифре и бальном платье. Приехала и известная, как la femme la plus séduisante de Pétersbourg 1, молодая, маленькая княгиня Болконская, прошлую зиму вышедшая замуж и теперь не выезжавшая в большой свет по причине своей беременности, но ездившая еще на небольшие вечера. Приехал князь Ипполит, сын князя Василия, с Мортемаром, которого он представил; приехал и аббат Морио и многие другие. — Вы не видали еще, — или: — вы не знакомы с ma tante? 2 — говорила Анна Павловна приезжавшим гостям и весьма серьезно подводила их к маленькой старушке в высоких бантах, выплывшей из другой комнаты, как скоро стали приезжать гости, называла их по имени, медленно переводя глаза с гостя на ma tante, и потом отходила. Все гости совершали обряд приветствования никому не известной, никому не интересной и не нужной тетушки. Анна Павловна с грустным, торжественным участием следила за их приветствиями, молчаливо одобряя их. Ma tante каждому говорила в одних и тех же выражениях о его здоровье, о своем здоровье и о здоровье ее величества, которое нынче было, слава Богу, лучше. Все подходившие, из приличия не выказывая поспешности, с чувством облегчения исполненной тяжелой обязанности отходили от старушки, чтоб уж весь вечер ни разу не подойти к ней. Молодая княгиня Болконская приехала с работой в шитом золотом бархатном мешке. Ее хорошенькая, с чуть черневшимися усиками верхняя губка была коротка по зубам, но тем милее она открывалась и тем еще милее вытягивалась иногда и опускалась на нижнюю. Как это бывает у вполне привлекательных женщин, недостаток ее — короткость губы и полуоткрытый рот — казались ее особенною, собственно ее красотой. Всем было весело смотреть на эту полную здоровья и живости хорошенькую будущую мать, так легко переносившую свое положение. Старикам и скучающим, мрачным молодым людям казалось, что они сами делаются похожи на нее, побыв и поговорив несколько времени с ней. Кто говорил с ней и видел при каждом слове ее светлую улыбочку и блестящие белые зубы, которые виднелись беспрестанно, тот думал, что он особенно нынче любезен. И это думал каждый."

# %%
#разделили по пробелу
a = str.lower(sample_test).split()
prep = {'.',',','?','!',':',';','-'}

b = list()
#теперь разделим слова, у которых на конце остался знак преипнания, и запишем в список b
for i in range(len(a)):
    if a[i][-1:] in prep:
        if len(a[i][-1:]) != 0:
            b.append(a[i][:-1])
            
        b.append(a[i][-1:])
    else:
        b.append(a[i])

#подсчет вхождений        
d = dict()
for x in b:
    if x not in d:
        d[x] = 1
    else:
        d[x] += 1
    
print(d)
# Out:
# {'гостиная': 1, 'анны': 1, 'павловны': 1, 'начала': 1, 'понемногу': 1, 'наполняться': 1, '.': 17, 'приехала': 4, 'высшая': 1, 'знать': 1, 'петербурга': 1, ',': 41, 'люди': 1, 'самые': 1, 'разнородные': 1, 'по': 5, 'возрастам': 1, 'и': 20, 'характерам': 1, 'но': 3, 'одинаковые': 1, 'обществу': 1, 'в': 6, 'каком': 1, 'все': 3, 'жили': 1, ';': 2, 'дочь': 1, 'князя': 2, 'василия': 2, 'красавица': 1, 'элен': 1, 'заехавшая': 1, 'за': 2, 'отцом': 1, 'чтобы': 1, 'с': 10, 'ним': 1, 'вместе': 1, 'ехать': 1, 'на': 6, 'праздник': 1, 'посланника': 1, 'она': 2, 'была': 2, 'шифре': 1, 'бальном': 1, 'платье': 1, 'известная': 1, 'как': 3, 'la': 2, 'femme': 1, 'plus': 1, 'séduisante': 1, 'de': 1, 'pétersbourg': 1, '1': 1, 'молодая': 2, 'маленькая': 1, 'княгиня': 2, 'болконская': 2, 'прошлую': 1, 'зиму': 1, 'вышедшая': 1, 'замуж': 1, 'теперь': 1, 'не': 8, 'выезжавшая': 1, 'большой': 1, 'свет': 1, 'причине': 1, 'своей': 1, 'беременности': 1, 'ездившая': 1, 'еще': 3, 'небольшие': 1, 'вечера': 1, 'приехал': 2, 'князь': 1, 'ипполит': 1, 'сын': 1, 'мортемаром': 1, 'которого': 1, 'он': 2, 'представил': 1, 'аббат': 1, 'морио': 1, 'многие': 1, 'другие': 1, '—': 6, 'вы': 2, 'видали': 1, 'или': 1, ':': 1, 'знакомы': 1, 'ma': 3, 'tante': 3, '?': 1, '2': 1, 'говорила': 2, 'анна': 2, 'павловна': 2, 'приезжавшим': 1, 'гостям': 1, 'весьма': 1, 'серьезно': 1, 'подводила': 1, 'их': 4, 'к': 2, 'маленькой': 1, 'старушке': 1, 'высоких': 1, 'бантах': 1, 'выплывшей': 1, 'из': 2, 'другой': 1, 'комнаты': 1, 'скоро': 1, 'стали': 1, 'приезжать': 1, 'гости': 2, 'называла': 1, 'имени': 1, 'медленно': 1, 'переводя': 1, 'глаза': 1, 'гостя': 1, 'потом': 1, 'отходила': 1, 'совершали': 1, 'обряд': 1, 'приветствования': 1, 'никому': 2, 'известной': 1, 'интересной': 1, 'нужной': 1, 'тетушки': 1, 'грустным': 1, 'торжественным': 1, 'участием': 1, 'следила': 1, 'приветствиями': 1, 'молчаливо': 1, 'одобряя': 1, 'каждому': 1, 'одних': 1, 'тех': 1, 'же': 1, 'выражениях': 1, 'о': 3, 'его': 1, 'здоровье': 3, 'своем': 1, 'ее': 6, 'величества': 1, 'которое': 1, 'нынче': 2, 'было': 2, 'слава': 1, 'богу': 1, 'лучше': 1, 'подходившие': 1, 'приличия': 1, 'выказывая': 1, 'поспешности': 1, 'чувством': 1, 'облегчения': 1, 'исполненной': 1, 'тяжелой': 1, 'обязанности': 1, 'отходили': 1, 'от': 1, 'старушки': 1, 'чтоб': 1, 'уж': 1, 'весь': 1, 'вечер': 1, 'ни': 1, 'разу': 1, 'подойти': 1, 'ней': 3, 'работой': 1, 'шитом': 1, 'золотом': 1, 'бархатном': 1, 'мешке': 1, 'хорошенькая': 1, 'чуть': 1, 'черневшимися': 1, 'усиками': 1, 'верхняя': 1, 'губка': 1, 'коротка': 1, 'зубам': 1, 'тем': 2, 'милее': 2, 'открывалась': 1, 'вытягивалась': 1, 'иногда': 1, 'опускалась': 1, 'нижнюю': 1, 'это': 2, 'бывает': 1, 'у': 1, 'вполне': 1, 'привлекательных': 1, 'женщин': 1, 'недостаток': 1, 'короткость': 1, 'губы': 1, 'полуоткрытый': 1, 'рот': 1, 'казались': 1, 'особенною': 1, 'собственно': 1, 'красотой': 1, 'всем': 1, 'весело': 1, 'смотреть': 1, 'эту': 1, 'полную': 1, 'здоровья': 1, 'живости': 1, 'хорошенькую': 1, 'будущую': 1, 'мать': 1, 'так': 1, 'легко': 1, 'переносившую': 1, 'свое': 1, 'положение': 1, 'старикам': 1, 'скучающим': 1, 'мрачным': 1, 'молодым': 1, 'людям': 1, 'казалось': 1, 'что': 2, 'они': 1, 'сами': 1, 'делаются': 1, 'похожи': 1, 'нее': 1, 'побыв': 1, 'поговорив': 1, 'несколько': 1, 'времени': 1, 'кто': 1, 'говорил': 1, 'видел': 1, 'при': 1, 'каждом': 1, 'слове': 1, 'светлую': 1, 'улыбочку': 1, 'блестящие': 1, 'белые': 1, 'зубы': 1, 'которые': 1, 'виднелись': 1, 'беспрестанно': 1, 'тот': 1, 'думал': 2, 'особенно': 1, 'любезен': 1, 'каждый': 1}

# %% [markdown]
# # Часть 2. Numpy

# %%
#Реализуйте функции, которые будут считать следующие расстояние между векторами:
#1. Евклидово расстояние
def euclid(x,y):
    return sum((x-y)**2)**0.5

#2. Хеммингово расстояние
def hem(x,y):
    z = abs(x-y)
    mask = abs(z)>0
    return len(z[mask])

#3. Расстояние Чебышева
def cheb(x,y):
    z = abs(x-y)
    return np.max(z)

# Вектора в функцию подаются как numpy.array.

# %% [markdown]
# # Часть 3. Pandas

# %%
#Считайте датасет из файла train.csv - это данные о выживаемости на Титанике
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Выведите основную информацию о датасете - число пропусков, средние значения и т.д. 
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Посчитайте процент выживаемости у каждого класса пассажиров (Pclass) 
df.groupby('Pclass')['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
#Посчитайте процнт выживаемости для мужчин и женщин
df.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
#Выведите самое популярное мужское и самое популярное женское имя на корабле
def f(s):
    if s.find('(') == -1: 
        return s.split('.')[1].split()[0] 
    
    elif len(s.split('('))>1:
        return s.split('(')[1].split()[0] 
    else:
        return s.split('(')[0]

# %%
df['short_name'] = df['Name'].apply(f)

# %%
#Мужское 
df['short_name'][df['Sex'] == 'male'].value_counts()[:1]
# Out:
# William    35
# Name: short_name, dtype: int64

# %%
#Женское
df['short_name'][df['Sex'] == 'female'].value_counts()[:1]
# Out:
# Anna    14
# Name: short_name, dtype: int64

# %%
#Выведите самое популярное мужское и самое популярное женское имя на корабле в каждом классе
for i in range(1,4):
    for j in ['male','female']:
        print("Sex:",j, "Pclass: ",i , df['short_name'][(df['Sex'] == j) & 
              (df['Pclass'] == i)].value_counts()[:1].index[0])
# Out:
# Sex: male Pclass:  1 William
# Sex: female Pclass:  1 Margaret
# Sex: male Pclass:  2 William
# Sex: female Pclass:  2 Elizabeth
# Sex: male Pclass:  3 William
# Sex: female Pclass:  3 Anna

# %%
#Выведите количества n-местных кабин (в которых было 2, 3, 4, ... человека)

b = list(df.groupby('Cabin')['PassengerId'].count())

d = dict()
for x in b:
    if x not in d:
        d[x] = 1
    else:
        d[x] += 1

print(d)
# Out:
# {1: 101, 2: 38, 4: 3, 3: 5}

# %%
#Выведите часть таблицы с пассажирами, возраст которых больше 44 лет.
df[df['Age'] > 44]
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 15            16         1       2
# 33            34         0       2
# 52            53         1       1
# ..           ...       ...     ...
# 857          858         1       1
# 862          863         1       1
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 33                               Wheadon, Mr. Edward H    male  66.0      0
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# 857                             Daly, Mr. Peter Denis     male  51.0      0
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 873                        Vander Cruyssen, Mr. Victor    male  47.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
#
#      Parch      Ticket     Fare Cabin Embarked short_name
# 6        0       17463  51.8625   E46        S    Timothy
# 11       0      113783  26.5500  C103        S  Elizabeth
# 15       0      248706  16.0000   NaN        S       Mary
# 33       0  C.A. 24579  10.5000   NaN        S     Edward
# 52       0    PC 17572  76.7292   D33        C       Myna
# ..     ...         ...      ...   ...      ...        ...
# 857      0      113055  26.5500   E17        S      Peter
# 862      0       17466  25.9292   D17        S   Margaret
# 871      1       11751  52.5542   D35        S     Sallie
# 873      0      345765   9.0000   NaN        S     Victor
# 879      1       11767  83.1583   C50        C       Lily
#
# [115 rows x 13 columns]

# %%
#Выведите часть таблицы с пассажирами, возраст которых меньше 44 лет и которые мужского пола.
df[(df['Age'] > 44) & (df['Sex'] == 'male')]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 33            34         0       2           Wheadon, Mr. Edward H  male
# 54            55         0       1  Ostby, Mr. Engelhart Cornelius  male
# 62            63         0       1     Harris, Mr. Henry Birkhardt  male
# 92            93         0       1     Chaffee, Mr. Herbert Fuller  male
# ..           ...       ...     ...                             ...   ...
# 771          772         0       3         Jensen, Mr. Niels Peder  male
# 789          790         0       1        Guggenheim, Mr. Benjamin  male
# 851          852         0       3             Svensson, Mr. Johan  male
# 857          858         1       1          Daly, Mr. Peter Denis   male
# 873          874         0       3     Vander Cruyssen, Mr. Victor  male
#
#       Age  SibSp  Parch       Ticket     Fare    Cabin Embarked short_name
# 6    54.0      0      0        17463  51.8625      E46        S    Timothy
# 33   66.0      0      0   C.A. 24579  10.5000      NaN        S     Edward
# 54   65.0      0      1       113509  61.9792      B30        C  Engelhart
# 62   45.0      1      0        36973  83.4750      C83        S      Henry
# 92   46.0      1      0  W.E.P. 5734  61.1750      E31        S    Herbert
# ..    ...    ...    ...          ...      ...      ...      ...        ...
# 771  48.0      0      0       350047   7.8542      NaN        S      Niels
# 789  46.0      0      0     PC 17593  79.2000  B82 B84        C   Benjamin
# 851  74.0      0      0       347060   7.7750      NaN        S      Johan
# 857  51.0      0      0       113055  26.5500      E17        S      Peter
# 873  47.0      0      0       345765   9.0000      NaN        S     Victor
#
# [79 rows x 13 columns]

# %% [markdown]
# # Часть 4. Визуализация
# ### Вопросы по данным из датасета df, который использовался на воркшопе по визуализации.

# %%
#Чтобы не переносить кучу ячеек из ноутбука по визуализации, я сохранил df в csv и сейчас считаю его
df = pd.read_csv('output.csv')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (0,1,2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#   Province/State  Country/Region          Last Update  Confirmed  Deaths  \
# 0          Hubei  Mainland China  2020-02-26T14:13:10    65187.0  2615.0
# 1      Guangdong  Mainland China  2020-02-26T10:33:02     1347.0     7.0
# 2          Henan  Mainland China  2020-02-26T10:33:02     1271.0    19.0
# 3            NaN     South Korea  2020-02-26T11:03:11     1261.0    12.0
# 4       Zhejiang  Mainland China  2020-02-26T10:33:02     1205.0     1.0
#
#    Recovered  FIPS Admin2 Province_State Country_Region Last_Update  Lat  \
# 0    20969.0   NaN    NaN            NaN            NaN         NaN  NaN
# 1      851.0   NaN    NaN            NaN            NaN         NaN  NaN
# 2     1033.0   NaN    NaN            NaN            NaN         NaN  NaN
# 3       22.0   NaN    NaN            NaN            NaN         NaN  NaN
# 4      867.0   NaN    NaN            NaN            NaN         NaN  NaN
#
#    Long_  Active Combined_Key  Incidence_Rate  Case-Fatality_Ratio  Latitude  \
# 0    NaN     NaN          NaN             NaN                  NaN       NaN
# 1    NaN     NaN          NaN             NaN                  NaN       NaN
# 2    NaN     NaN          NaN             NaN                  NaN       NaN
# 3    NaN     NaN          NaN             NaN                  NaN       NaN
# 4    NaN     NaN          NaN             NaN                  NaN       NaN
#
#    Longitude
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %% [markdown]
# Создайте признак 'date', в котором будет храниться дата (гггг-мм-дд). Постройте график зависимости количества строк от даты в этих строках. Найдите минимальное количество строк за день в датасете за период с 01.04.2020 по 31.08.2020.
#
# Варианты:
# - 1990
# - 2472
# - 472
# - 103
# - 1984

# %%
df['date'] = pd.to_datetime(df['Last_Update']).apply(lambda x: x.date())

# %%
#графики в svg выглядят более четкими
# %config InlineBackend.figure_format = 'svg' 

#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 8, 5

# %%
df['date'].value_counts().sort_index().plot()

# %%
df['date'][(df['date'] > pd.to_datetime('2020-04-01')) &
           (df['date'] < pd.to_datetime('2020-08-31')) ].value_counts(ascending = True)[:1]
# Out:
# 2020-04-23    103
# Name: date, dtype: int64

# %% [markdown]
# Найдите максимальное количество строк за день в датасете за период с 01.04.2020 по 31.08.2020.
#
# Варианты:
# - 3990
# - 3952
# - 2472
# - 5120
# - 7025

# %%
df['date'][(df['date'] > pd.to_datetime('2020-04-01')) &
           (df['date'] < pd.to_datetime('2020-08-31'))].value_counts(ascending = False)[:1]
# Out:
# 2020-08-04    4058
# Name: date, dtype: int64

# %% [markdown]
# Постройте подобный график только для России. С какого числа Россия начала предоставлять информацию в разбивке по областям?
#
# Варианты:
# - 01.04.2020
# - 06.04.2020
# - 31.05.2020
# - 01.06.2020
# - 02.06.2020

# %%
df['date'][df['Country_Region'] == 'Russia'].value_counts().sort_index().plot()

# %%
df[(df['Country_Region']=='Russia') & (df['Province_State'].isnull() == False) ]
                                [['Province_State','date']].sort_values(by='date')
# Out:
#                    Province_State        date
# 300780           Zabaykalsky Krai  2020-06-02
# 300679           Saint Petersburg  2020-06-02
# 300673              Ryazan Oblast  2020-06-02
# 300672              Rostov Oblast  2020-06-02
# 300650               Pskov Oblast  2020-06-02
# ...                           ...         ...
# 470034              Ryazan Oblast  2020-10-10
# 470035           Saint Petersburg  2020-10-10
# 470037            Sakhalin Oblast  2020-10-10
# 470028            Orenburg Oblast  2020-10-10
# 470036  Sakha (Yakutiya) Republic  2020-10-10
#
# [10873 rows x 2 columns]

# %% [markdown]
# Ответ 02.06.2020

# %% [markdown]
# Постройте гистограмму ежедневного прироста подтверждённых случаев заболевания.
# Когда в России был первый пик заболеваемости?
#
# Варианты:
# - 03.04.2020
# - 19.04.2020
# - 06.05.2020
# - 12.05.2020
# - 07.06.2020

# %%
df_rus = df[df['Country_Region']=='Russia'].groupby('date')['Confirmed'].sum().copy()

# %%
df_rus_day = df_rus - df_rus.shift(1)

# %%
hist_rus = df_rus_day.plot(kind = 'hist', title = 'Гистограмма распределения прироста в России')

# %%
plot_rus_day = df_rus_day.plot(title = 'Прирост числа подтвержденных заболеваний в России по дням ')

# %%
df_rus_day.sort_values(ascending = False)[:5]
# Out:
# date
# 2020-10-10    11969.0
# 2020-05-12    11656.0
# 2020-10-07    11481.0
# 2020-10-09    11345.0
# 2020-05-08    11231.0
# Name: Confirmed, dtype: float64

# %% [markdown]
# Ответ: первый пик был 12.05.2020

# %% [markdown]
# Постройте гистограммы подтверждённых случаев заболеваний в России и Бразилии, чтобы выбрать правильный ответ.
#
# Варианты:
# - В июле и августе ежедневное количество подтверждённых случаев заражения в Бразилии всегда выше, чем в России.
# - В летние месяцы ежедневное количество подтверждённых случаев заражения в Бразилии впервые превзошло такой же показатель в России.
# - В России более заметна недельная сезонность регистрации заболеваемости.
# - В летние месяцы отсутствуют данные за несколько дней в обеих странах.
# - Ни один ответ не верен.

# %%
df_bra = df[df['Country_Region']=='Brazil'].groupby('date')['Confirmed'].sum().copy()

# %%
df_bra_day = df_bra - df_bra.shift(1)

# %%
hist_bra = df_bra_day.plot(kind = 'hist', title = 'Гистограмма распределения прироста в Бразилии')

# %%
plot_bra_day = df_bra_day.plot(title = 'Прирост числа подтвержденных заболеваний в Бразилии по дням ')

# %%
plt.plot(df_rus_day, label = 'Russia')
plt.plot(df_bra_day, label = 'Brazil')
plt.title('Число подтвержденных случав в России/Бразилии')
plt.legend()

# %%
df_diff_bra_rus = df_bra - df_rus
plt.plot(df_diff_bra_rus)
plt.title('Число подтвержденных случав Бразилия минус Россия')
# Out:
# Text(0.5, 1.0, 'Число подтвержденных случав Бразилия минус Россия')

# %%
df_diff_bra_rus[df_diff_bra_rus.index == pd.to_datetime('2020-05-31') ]
# Out:
# date
# 2020-05-31    101865.0
# Name: Confirmed, dtype: float64

# %% [markdown]
# Значит, число подтвержденных случаев в Бразилии превысило число в России раньше лета.

# %%
len(df_rus[(df_rus.index > pd.to_datetime('2020-05-31')) & (df_rus.index < pd.to_datetime('2020-09-01'))])
# Out:
# 92

# %%
len(df_rus[(df_bra.index > pd.to_datetime('2020-05-31')) & (df_bra.index < pd.to_datetime('2020-09-01'))])
# Out:
# 92

# %% [markdown]
# Значит, в летние месяцы есть все данные в обеих странах.

# %%
df_rus_week = df_rus - df_rus.shift(7)
df_bra_week = df_bra - df_bra.shift(7)

# %%
plt.plot(df_rus_week, label = 'Russia')
plt.plot(df_bra_week, label = 'Brazil')
plt.title('Еженедельный прирост в России/Бразилии')
plt.legend()

# %% [markdown]
# Ответ: В июле и августе ежедневное количество подтверждённых случаев заражения в Бразилии всегда выше, чем в России.
#       В России более заметна недельная сезонность регистрации заболеваемости.
